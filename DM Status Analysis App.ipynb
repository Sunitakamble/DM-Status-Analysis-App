# %%
import gradio as gr
def DM(Fasting, PPG):
    if Fasting < 100 and PPG < 140:
        return "Normal Sugar"
    elif 101 <= Fasting <= 125 and 140 <= PPG <= 200:
        return "Impaired Glucose"
    elif 126 <= Fasting <= 200 and 200 <= PPG <= 400:
        return "First Stage diabetes mellitus"
    elif Fasting >= 200 and PPG < 400:
        return "Second Stage diabetes mellitus"
    else:
        return "Undefined measure"

interface = gr.Interface(fn=DM,inputs=["number", "number"],  
    outputs='text', title="ANALYSIS OF Diabetes mellitus")

interface.launch()
# Out:
# Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Exception in thread Thread-7 (_do_normal_analytics_request):
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda\Lib\site-packages\httpx\_transports\default.py", line 69, in map_httpcore_exceptions
#     yield
#   File "C:\Users\DELL\anaconda\Lib\site-packages\httpx\_transports\default.py", line 233, in handle_request
#     resp = self._pool.handle_request(req)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\DELL\anaconda\Lib\site-packages\httpcore\_sync\connection_pool.py", line 216, in handle_request
#     raise exc from None
#   File "C:\Users\DELL\anaconda\Lib\site-packages\httpcore\_sync\connection_pool.py", line 196, in handle_request
#     response = connection.handle_request(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\DELL\anaconda\Lib\site-packages\httpcore\_sync\connection.py", line 99, in handle_request
#     raise exc
#   File "C:\Users\DELL\anaconda\Lib\site-packages\httpcore\_sync\connection.py", line 76, in handle_request
#     stream = self._connect(request)
#              ^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\DELL\anaconda\Lib\site-packages\httpcore\_sync\connection.py", line 154, in _connect
#     stream = stream.start_tls(**kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\DELL\anaconda\Lib\site-packages\httpcore\_backends\sync.py", line 152, in start_tls
#     with map_exceptions(exc_map):
#   File "C:\Users\DELL\anaconda\Lib\contextlib.py", line 158, in __exit__
#     self.gen.throw(typ, value, traceback)
#   File "C:\Users\DELL\anaconda\Lib\site-packages\httpcore\_exceptions.py", line 14, in map_exceptions
#     raise to_exc(exc) from exc
# httpcore.ConnectTimeout: _ssl.c:989: The handshake operation timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda\Lib\threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda\Lib\threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\DELL\anaconda\Lib\site-packages\gradio\analytics.py", line 70, in _do_normal_analytics_request
#     data["ip_address"] = get_local_ip_address()
#                          ^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\DELL\anaconda\Lib\site-packages\gradio\analytics.py", line 131, in get_local_ip_address
#     ip_address = httpx.get(
#                  ^^^^^^^^^^
#   File "C:\Users\DELL\anaconda\Lib\site-packages\httpx\_api.py", line 198, in get
#     return request(
#            ^^^^^^^^
#   File "C:\Users\DELL\anaconda\Lib\site-packages\httpx\_api.py", line 106, in request
#     return client.request(
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\DELL\anaconda\Lib\site-packages\httpx\_client.py", line 827, in request
#     return self.send(request, auth=auth, follow_redirects=follow_redirects)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\DELL\anaconda\Lib\site-packages\httpx\_client.py", line 914, in send
#     response = self._send_handling_auth(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\DELL\anaconda\Lib\site-packages\httpx\_client.py", line 942, in _send_handling_auth
#     response = self._send_handling_redirects(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\DELL\anaconda\Lib\site-packages\httpx\_client.py", line 979, in _send_handling_redirects
#     response = self._send_single_request(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\DELL\anaconda\Lib\site-packages\httpx\_client.py", line 1015, in _send_single_request
#     response = transport.handle_request(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\DELL\anaconda\Lib\site-packages\httpx\_transports\default.py", line 232, in handle_request
#     with map_httpcore_exceptions():
#   File "C:\Users\DELL\anaconda\Lib\contextlib.py", line 158, in __exit__
#     self.gen.throw(typ, value, traceback)
#   File "C:\Users\DELL\anaconda\Lib\site-packages\httpx\_transports\default.py", line 86, in map_httpcore_exceptions
#     raise mapped_exc(message) from exc
# httpx.ConnectTimeout: _ssl.c:989: The handshake operation timed out
# Exception in thread Thread-9 (_do_normal_analytics_request):
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda\Lib\site-packages\httpx\_transports\default.py", line 69, in map_httpcore_exceptions
#     yield
#   File "C:\Users\DELL\anaconda\Lib\site-packages\httpx\_transports\default.py", line 233, in handle_request
#     resp = self._pool.handle_request(req)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\DELL\anaconda\Lib\site-packages\httpcore\_sync\connection_pool.py", line 216, in handle_request
#     raise exc from None
#   File "C:\Users\DELL\anaconda\Lib\site-packages\httpcore\_sync\connection_pool.py", line 196, in handle_request
#     response = connection.handle_request(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\DELL\anaconda\Lib\site-packages\httpcore\_sync\connection.py", line 99, in handle_request
#     raise exc
#   File "C:\Users\DELL\anaconda\Lib\site-packages\httpcore\_sync\connection.py", line 76, in handle_request
#     stream = self._connect(request)
#              ^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\DELL\anaconda\Lib\site-packages\httpcore\_sync\connection.py", line 154, in _connect
#     stream = stream.start_tls(**kwargs)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\DELL\anaconda\Lib\site-packages\httpcore\_backends\sync.py", line 152, in start_tls
#     with map_exceptions(exc_map):
#   File "C:\Users\DELL\anaconda\Lib\contextlib.py", line 158, in __exit__
#     self.gen.throw(typ, value, traceback)
#   File "C:\Users\DELL\anaconda\Lib\site-packages\httpcore\_exceptions.py", line 14, in map_exceptions
#     raise to_exc(exc) from exc
# httpcore.ConnectTimeout: _ssl.c:989: The handshake operation timed out
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\DELL\anaconda\Lib\threading.py", line 1045, in _bootstrap_inner
#     self.run()
#   File "C:\Users\DELL\anaconda\Lib\threading.py", line 982, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Users\DELL\anaconda\Lib\site-packages\gradio\analytics.py", line 70, in _do_normal_analytics_request
#     data["ip_address"] = get_local_ip_address()
#                          ^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\DELL\anaconda\Lib\site-packages\gradio\analytics.py", line 131, in get_local_ip_address
#     ip_address = httpx.get(
#                  ^^^^^^^^^^
#   File "C:\Users\DELL\anaconda\Lib\site-packages\httpx\_api.py", line 198, in get
#     return request(
#            ^^^^^^^^
#   File "C:\Users\DELL\anaconda\Lib\site-packages\httpx\_api.py", line 106, in request
#     return client.request(
#            ^^^^^^^^^^^^^^^
#   File "C:\Users\DELL\anaconda\Lib\site-packages\httpx\_client.py", line 827, in request
#     return self.send(request, auth=auth, follow_redirects=follow_redirects)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\DELL\anaconda\Lib\site-packages\httpx\_client.py", line 914, in send
#     response = self._send_handling_auth(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\DELL\anaconda\Lib\site-packages\httpx\_client.py", line 942, in _send_handling_auth
#     response = self._send_handling_redirects(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\DELL\anaconda\Lib\site-packages\httpx\_client.py", line 979, in _send_handling_redirects
#     response = self._send_single_request(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\DELL\anaconda\Lib\site-packages\httpx\_client.py", line 1015, in _send_single_request
#     response = transport.handle_request(request)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\DELL\anaconda\Lib\site-packages\httpx\_transports\default.py", line 232, in handle_request
#     with map_httpcore_exceptions():
#   File "C:\Users\DELL\anaconda\Lib\contextlib.py", line 158, in __exit__
#     self.gen.throw(typ, value, traceback)
#   File "C:\Users\DELL\anaconda\Lib\site-packages\httpx\_transports\default.py", line 86, in map_httpcore_exceptions
#     raise mapped_exc(message) from exc
# httpx.ConnectTimeout: _ssl.c:989: The handshake operation timed out
